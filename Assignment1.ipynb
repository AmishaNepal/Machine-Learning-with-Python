# %%
#Question 1..............................

fname=input('Enter First Name')
lname=input('Enter Last Name')
print(f'"Hello, {fname} {lname}! Welcome to Python Programming.')
# Out:
# "Hello,  ! Welcome to Python Programming.

# %%
#Question 2................................

weight=int(input('Enter your height in cm'))
height=int(input('Enter your weight in kg'))
BMI=weight/(height/100)**2
print(f'The BMI value is {BMI:.2f}')
# Out:
# The BMI value is 555.56

# %%
#Question 3..................................

score=int(input('Enter your exam score'))
if(score>=90):
    print(f'A')
elif(score>=80 and score<90):
    print(f'B')
elif(score>=70 and score<80):
    print(f'C')
elif(score>=60 and score<70):
    print(f'D')
else:
    print(f'F')
# Out:
# B

# %%
#Question 4.................................

year=int(input("Enter a year"))
if(year%4==0 and year%100!=0 or year%400==0):
    print(f'{year} is a leap year')
else:
    print(f'{year} is not a leap year')
# Out:
# 1996 is a leap year

# %%
#Question 5.................................

n=5
print(f'The multiples of {n} from 1 to 50 are:')
for i in range(1,11):
    print(f'{n*i}')
# Out:
# The multiples of 5 from 1 to 50 are:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
#Question 6..........................

flag=True
while(flag):
    n=int(input("Enter a positive number"))
    if n>0:
        print('You have entered {n}')
    if n<0:
        flag=False

# %%
#Question 7..........................

# %%
#Question 8.....................................

def calculate_area(radius):
    return(3.14*radius*radius)
print(f'The area of the circle is:')
calculate_area(3)
# Out:
# The area of the circle is:
# 28.259999999999998

# %%
a=int(input('Enter a number'))
type(a)
# Out:
# int

# %%
#Question 9.....................................
aString='madam'
def is_palindrome(aString):
    if(aString== aString[::-1]):
        return True
    else:
        return False
print(is_palindrome(aString))
# Out:
# True

# %%
#Question 10.................................

def check_prime(num):
    if(num%num==0 and num%1==0):
        return True
    else:
        return False
check_prime(20)
# Out:
# True
