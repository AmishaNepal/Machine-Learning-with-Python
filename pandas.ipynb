# %%
import pandas as pd

data={
    'Name':['Amisha','Alkesh','Tahal','Tola'],
    'Math':[97,98,99,100],
    'Science':[80,89,90,91],
    'English':[92,93,94,95]

}
df=pd.DataFrame(data)
print(df)
# Out:
#      Name  Math  Science  English
# 0  Amisha    97       80       92
# 1  Alkesh    98       89       93
# 2   Tahal    99       90       94
# 3    Tola   100       91       95

# %%
#Use .info() to find out what type of data each column contains

print(df.info(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     4 non-null      object
#  1   Math     4 non-null      int64
#  2   Science  4 non-null      int64
#  3   English  4 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 260.0+ bytes
# None

# %%
#Use .head() to show the first 2 rows of the dataset.

print(df.head(2))
# Out:
#      Name  Math  Science  English
# 0  Amisha    97       80       92
# 1  Alkesh    98       89       93

# %%
#Use .describe() to get a summary of numerical columns in the dataset.

print(df.describe())
# Out:
#              Math    Science    English
# count    4.000000   4.000000   4.000000
# mean    98.500000  87.500000  93.500000
# std      1.290994   5.066228   1.290994
# min     97.000000  80.000000  92.000000
# 25%     97.750000  86.750000  92.750000
# 50%     98.500000  89.500000  93.500000
# 75%     99.250000  90.250000  94.250000
# max    100.000000  91.000000  95.000000

# %%
#Fill any missing values in the Price column with the mean price of all products.
df= pd.read_csv('customers.csv')
print(df)
# Out:
#    Customer_ID     Name  Age                Email           City
# 0            1    Alice   28    alice@example.com       New York
# 1            2      Bob   35      bob@example.com    Los Angeles
# 2            3  Charlie   22  charlie@example.com  San Francisco
# 3            4    David   40    david@example.com        Chicago
# 4            5      Eve   29      eve@example.com        Houston
# 5            6    Frank   32    frank@example.com          Miami
# 6            7    Grace   27    grace@example.com        Seattle
# 7            8   Hannah   38   hannah@example.com         Boston
# 8            9      Ian   25                  NaN         Denver
# 9           10     Jack   30     jack@example.com            NaN

# %%
#Checking missing values
print(df.isnull().sum())
# Out:
# Customer_ID    0
# Name           0
# Age            0
# Email          1
# City           1
# dtype: int64
