# %%
x=10
print(f'Value of x is {x}')
print(type(x))
# Out:
# Value of x is 10
# <class 'int'>

# %%
a=10
b=3
print(f'Sum of {a} and {b} is {a+b}')
print(f'Sum of {a} and {b} is {a-b}')
print(f'Sum of {a} and {b} is {a*b}')
print(f'Quotient of {a} and {b} is {a/b:.3f}')
print(f'Remainder of {a} and {b} is {a%b}')
print(f'Power of {a} raised {b} is {a**b}')
# Out:
# Sum of 10 and 3 is 13
# Sum of 10 and 3 is 7
# Sum of 10 and 3 is 30
# Quotient of 10 and 3 is 3.333
# Remainder of 10 and 3 is 1
# Power of 10 raised 3 is 1000

# %%
a=10
b=3
print(f'a>b {a>b}')
# Out:
# a>b True

# %%
a=True
b=False
print(f'{a} and {b} {a and b}')
print(f'{a} and {b} {a or b}')
print(f'not {b} {a and b}')
# Out:
# True and False False
# True and False True
# not False False

# %%
name=input("Your name?")
print(name)
print(type(name))
# Out:
# Amisha
# <class 'str'>

# %%
principal=float (input("Enter Principal"))
rate=float (input("Enter rate"))
time=float (input("Enter Time"))
si=(principal*rate*time)/100
amount=principal+si
print(f'The Simple Interest is Rs.{si} and amount is Rs.{amount}')
# Out:
# The Simple Interest is Rs.192.0 and amount is Rs.2592.0

# %%
n=int(input("Enter a number"))
rem=n%2
if(rem==0):
    print(f'{n} is Even')
else:
    print(f'{n} is Odd')
# Out:
# 24 is Even

# %%
a=5
b=60
c=4
rem=n%2
if(a>b and a>c):
    print(f'{a} is greatest')
elif(b>a and b>c):
    print(f'{b} is greatest')
else:
    print(f'{c} is greatest')
# Out:
# 60 is greatest

# %%
for i in range(1,101,20):
    print(i,end=' ')
# Out:
# 1 21 41 61 81

# %%
n=int(input('Enter a Number'))
fact=1
for i in range(1,n+1):
    fact=fact*i
print(f'The fact of{N} is {fact}')
# Out:
# The fact of4 is 2432902008176640000

# %%
n=20
for i in range(1,11):
    print(f'{n}*{i}={n*i}')
# Out:
# 20*1=20
# 20*2=40
# 20*3=60
# 20*4=80
# 20*5=100
# 20*6=120
# 20*7=140
# 20*8=160
# 20*9=180
# 20*10=200

# %%
a=10
b=12
if(b==0):
    print(f'{a} is the GCD')
else:
    while(b!=0):
        r=a%b
        a=b
        b=r
print(f'{a} is the GCD')
# Out:
# 2 is the GCD

# %%
def checkEven(n):
    if(n%2 == 0):
        print(f'{n} is EVEN')
    else:
        print(f'{n} is ODD')
checkEven(200)
# Out:
# 200 is EVEN

# %%
def avg(a,b,c):
    return (a+b+c)/3
a,b,c = 2,3,4
print(f'The average of {a},{b} and {c} is {avg(a,b,c)}')
# Out:
# The average of 2,3 and 4 is 3.0

# %%
def sum(N):
    sum=0
    for i in range(1,1+N):
        sum +=i
    return sum
N=50
print(f'The sum upto {N} is {sum(N)}')
# Out:
# The sum upto 50 is 1275

# %%
list=['Amisha',1,1.2]
print(list)
# Out:
# ['Amisha', 1, 1.2]

# %%
list.index("Amisha")
# Out:
# 0

# %%
list[0]="Amu"
print(list)
# Out:
# ['Amu', 1, 1.2]

# %%
a=[]
b=list()

# %%
c=[10,20,30]
c.pop(1)
print(c)
# Out:
# [10, 30]

# %%
d=[4,6,1,2,0]
d.sort()
print(d)
max(d)
min(d)
len(d)
# Out:
# [0, 1, 2, 4, 6]
# 5

# %%
data=input("Enter three numbers")
data=data.spilt()
data=[int(num) for num in data]
a,b,c=data
print(f'a={a},b={b},c={c}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 2
#       1 data=input("Enter three numbers")
# ----> 2 data=data.spilt()
#       3 data=[int(num) for num in data]
#       4 a,b,c=data
#
# AttributeError: 'str' object has no attribute 'spilt'
