# %%
from ultralytics import YOLO

model=YOLO("YOLO11s.pt")

# %%
model.train(
    data="C:\\Users\\Dell\\Desktop\\Python\\Dataset\\data.yaml",
    epochs=5,
    batch=16,
    imgsz=640,
    workers=2,
    device="cpu"
)
# Out:
# Ultralytics 8.3.94  Python-3.13.2 torch-2.6.0+cpu CPU (Intel Core(TM) i5-8265U 1.60GHz)
# ...
