# %%
from ultralytics import YOLO

model=YOLO("YOLO11n.pt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from ultralytics import YOLO
# ----> 3 model=YOLO("YOLO11n.pt")
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\models\yolo\model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\model.py:148, in Model.__init__(self, model, task, verbose)
#     146     self._new(model, task=task, verbose=verbose)
#     147 else:
# --> 148     self._load(model, task=task)
#     150 # Delete super().training for accessing self.model.training
#     151 del self.training
#
# ...
