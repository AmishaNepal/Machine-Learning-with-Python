# %%
#Question 1...............................

string="Amisha Nepal"
count={}
for letter in string:
    if letter not in count:
        count[letter]=1
    else:
        count[letter]=count[letter] + 1
print(count)
# Out:
# {'A': 1, 'm': 1, 'i': 1, 's': 1, 'h': 1, 'a': 2, ' ': 1, 'N': 1, 'e': 1, 'p': 1, 'l': 1}

# %%
#Question 2...............................
dictionary={
    '1': 1*1,
    '2':2*2,
    '3':3*3,
    '4':4*4,
    '5':5*5
}
print(dictionary)
# Out:
# {'1': 1, '2': 4, '3': 9, '4': 16, '5': 25}

# %%
#Question 4...............................

from math import sqrt,pow,factorial
n=4
print(f'The square root of {n} is {sqrt(n)}')
print(f'The answer of {n}^2  is {pow(4,2)}')
print(f'The square root of {n} is {factorial(n)}')
# Out:
# The square root of 4 is 2.0
# The answer of 4^2  is 16.0
# The square root of 4 is 24
